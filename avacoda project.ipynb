# %%
##import all libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.linear_model import LogisticRegression,Lasso,LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor,GradientBoostingRegressor
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.decomposition import PCA
from scipy.stats import zscore
from sklearn.model_selection import cross_val_score

# %%
#fetching data into variable
df = pd.read_csv(r'C:\Users\rksan\Downloads\avocado.csv.zip')
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# 4  2015  Albany

# %%
#as we drop index column beacuse it just kind of id which have no effect on dataset
df.drop('Unnamed: 0',inplace=True,axis=1)

# %%
df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
#checking the total rows and total columns
df.shape
# Out:
# (18249, 13)

# %%
df.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
#Extract the Month from DOB into separate column
df['Month'] = pd.DatetimeIndex(df['Date']).month
df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015
# 1     9505.56     9408.07       97.49          0.0  conventional  2015
# 2     8145.35     8042.21      103.14          0.0  conventional  2015
# 3     5811.16     5677.40      133.76          0.0  conventional  2015
# 4     6183.95     5986.26      197.69          0.0  conventional  2015
#
#    region  Month
# 0  Albany     12
# 1  Albany     12
# 2  Albany     12
# 3  Albany     12
# 4  Albany     11

# %%
#Extract the Date from DOB into separate column
df['Date'] = pd.DatetimeIndex(df['Date']).day
df.head()
# Out:
#    Date  AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0    27          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1    20          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2    13          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3     6          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4    29          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags          type  year  region  Month
# 0     8603.62       93.25          0.0  conventional  2015  Albany     12
# 1     9408.07       97.49          0.0  conventional  2015  Albany     12
# 2     8042.21      103.14          0.0  conventional  2015  Albany     12
# 3     5677.40      133.76          0.0  conventional  2015  Albany     12
# 4     5986.26      197.69          0.0  conventional  2015  Albany     11

# %%
#checking the value counts of each date
df.Date.value_counts()
# Out:
# 4     756
# 11    756
# 18    755
# 25    755
# 8     648
# 10    648
# 19    648
# 5     648
# 22    648
# 15    648
# 24    648
# 17    648
# 26    648
# 12    648
# 1     648
# 3     648
# 27    540
# 28    540
# 7     540
# 13    540
# 21    540
# 29    540
# 20    540
# 14    540
# 6     539
# 2     432
# 31    432
# 23    432
# 9     432
# 30    432
# 16    432
# Name: Date, dtype: int64

# %%
#checking the value counts of each type
df.type.value_counts()
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %%
#co relation of total volume to total bag
df[['Total Volume','Total Bags']].corr()
# Out:
#               Total Volume  Total Bags
# Total Volume      1.000000    0.963047
# Total Bags        0.963047    1.000000

# %%
#checking the average year of volume of avacado per year
df.groupby('year')['Total Volume'].mean()
# Out:
# year
# 2015    7.810274e+05
# 2016    8.584206e+05
# 2017    8.623393e+05
# 2018    1.066928e+06
# Name: Total Volume, dtype: float64

# %%
#checking the organic type of avacado 
organic = df[df['type'] == 'organic']
organic
# Out:
#        Date  AveragePrice  Total Volume     4046     4225    4770  Total Bags  \
# 9126     27          1.83        989.55     8.16    88.59    0.00      892.80
# 9127     20          1.89       1163.03    30.24   172.14    0.00      960.65
# 9128     13          1.85        995.96    10.44   178.70    0.00      806.82
# 9129      6          1.84       1158.42    90.29   104.18    0.00      963.95
# 9130     29          1.94        831.69     0.00    94.73    0.00      736.96
# ...     ...           ...           ...      ...      ...     ...         ...
# 18244     4          1.63      17074.83  2046.96  1529.20    0.00    13498.67
# 18245    28          1.71      13888.04  1191.70  3431.50    0.00     9264.84
# 18246    21          1.87      13766.76  1191.92  2452.79  727.94     9394.11
# 18247    14          1.93      16205.22  1527.63  2981.04  727.01    10969.54
# 18248     7          1.62      17489.58  2894.77  2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags     type  year            region  \
# 9126       892.80        0.00          0.0  organic  2015            Albany
# 9127       960.65        0.00          0.0  organic  2015            Albany
# 9128       806.82        0.00          0.0  organic  2015            Albany
# 9129       948.52       15.43          0.0  organic  2015            Albany
# 9130       736.96        0.00          0.0  organic  2015            Albany
# ...           ...         ...          ...      ...   ...               ...
# 18244    13066.82      431.85          0.0  organic  2018  WestTexNewMexico
# 18245     8940.04      324.80          0.0  organic  2018  WestTexNewMexico
# 18246     9351.80       42.31          0.0  organic  2018  WestTexNewMexico
# 18247    10919.54       50.00          0.0  organic  2018  WestTexNewMexico
# 18248    11988.14       26.01          0.0  organic  2018  WestTexNewMexico
#
#        Month
# 9126      12
# 9127      12
# 9128      12
# 9129      12
# 9130      11
# ...      ...
# 18244      2
# 18245      1
# 18246      1
# 18247      1
# 18248      1
#
# [9123 rows x 14 columns]

# %%
#checking the mean of price at each year of organic type of avacado
organic.groupby('year')['AveragePrice'].mean()
# Out:
# year
# 2015    1.673324
# 2016    1.571684
# 2017    1.735521
# 2018    1.567176
# Name: AveragePrice, dtype: float64

# %%
#finding how much type of avacado is sell in last 4 year
df.groupby('year')['type'].value_counts()
# Out:
# year  type
# 2015  conventional    2808
#       organic         2807
# 2016  conventional    2808
#       organic         2808
# 2017  conventional    2862
#       organic         2860
# 2018  conventional     648
#       organic          648
# Name: type, dtype: int64

# %%
#total no of sale in each year of  4 years
df.groupby('year')['Total Volume'].count()
# Out:
# year
# 2015    5615
# 2016    5616
# 2017    5722
# 2018    1296
# Name: Total Volume, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
# Date            18249 non-null int64
# AveragePrice    18249 non-null float64
# Total Volume    18249 non-null float64
# 4046            18249 non-null float64
# 4225            18249 non-null float64
# 4770            18249 non-null float64
# Total Bags      18249 non-null float64
# Small Bags      18249 non-null float64
# Large Bags      18249 non-null float64
# XLarge Bags     18249 non-null float64
# type            18249 non-null object
# year            18249 non-null int64
# region          18249 non-null object
# Month           18249 non-null int64
# dtypes: float64(9), int64(3), object(2)
# memory usage: 1.9+ MB

# %%
##checking the null values

df.isnull().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# Month           0
# dtype: int64

# %%
#checking null values using heatmap

sns.heatmap(df.isnull())

# %%
df.describe()
# Out:
#                Date  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      15.662612      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std        8.776281      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        1.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%        8.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       16.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       23.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       31.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# std    1.074641e+05  9.862424e+05  7.461785e+05  2.439660e+05   17692.894652
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00       0.000000
# 25%    0.000000e+00  5.088640e+03  2.849420e+03  1.274700e+02       0.000000
# 50%    1.849900e+02  3.974383e+04  2.636282e+04  2.647710e+03       0.000000
# 75%    6.243420e+03  1.107834e+05  8.333767e+04  2.202925e+04     132.500000
# max    2.546439e+06  1.937313e+07  1.338459e+07  5.719097e+06  551693.650000
#
#                year         Month
# count  18249.000000  18249.000000
# mean    2016.147899      6.177215
# std        0.939938      3.534130
# min     2015.000000      1.000000
# 25%     2015.000000      3.000000
# 50%     2016.000000      6.000000
# 75%     2017.000000      9.000000
# max     2018.000000     12.000000

# %% [markdown]
# Above statatics data show that there multiple outliers mostly in XLargeBags There is also difference between mean and 50% value in some of the columns which used to get fix for better prediction

# %%
#checking  price that which year had max average price
sns.barplot(x = "year" , y = "AveragePrice" ,data=df )

# %% [markdown]
# so above graph showing that 2017 year is that year which has max average price

# %%
#checking ratio and price of month  that which month had max average price
sns.barplot(x = "Month" , y = "AveragePrice" ,data=df )

# %% [markdown]
# sept and october is the month where max no og average price is there

# %%
sns.lineplot(x = 'year', y = 'AveragePrice', data=df)

# %%
#checking which type had max average price
sns.barplot(x = "type" , y = "AveragePrice" ,data=df )

# %% [markdown]
# As organic type of avacado is having the more price per unit then conventional¶

# %%
plt.figure(figsize=(16,10))
sns.lineplot(x="Month", y="AveragePrice", hue='type', data=df)
plt.show()

# %% [markdown]
# Above graph shown that there is hike between month 8-10 of both type of avacado

# %%
plt.figure(figsize=(24,15))
sns.barplot(x='region',y='AveragePrice',data=df)
plt.xticks(rotation=90)
plt.xlabel('Region')
plt.ylabel('Average Price')
plt.title('ration of Price and Region')
# Out:
# Text(0.5, 1.0, 'ration of Price and Region')

# %% [markdown]
# above graph is showing that HartfordSpringfield ,SanFrancisco and NewYork are having more average price as compared to other region

# %%
date=df.groupby('Date').mean()
plt.figure(figsize=(12,10))
date['AveragePrice'].plot()
plt.title('Average_Price')
# Out:
# Text(0.5, 1.0, 'Average_Price')

# %% [markdown]
# above is showing on date 28,29 and 30 the price of avacado is high

# %%
month=df.groupby('Month').mean()
plt.figure(figsize=(12,10))
month['AveragePrice'].plot()
plt.title('Average_Price')
# Out:
# Text(0.5, 1.0, 'Average_Price')

# %% [markdown]
# in between august to october the price of avacado is much higher as comapared to other months

# %%
#plotting histogram for univariate analysis and checking the Normal Distribution
df.hist(figsize=(20,20), grid = True, layout = (4,4), bins = 30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001EBABAACE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EBAC14C6C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EBAC161B08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EBAC17C508>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001EBAB28BEC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EBAB2C58C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EBAB3002C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EBAB335DC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001EBAB33F988>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EBAB379B48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EBAB3E2148>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EBAB41B1C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001EBAB4552C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EBAB48E4C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EBAB4CAE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EBAB4FF848>]],
#       dtype=object)

# %%
df['type'].unique()
# Out:
# array(['conventional', 'organic'], dtype=object)

# %%
#Making the categorical data into numercial for better EDA
column = ['type','region']
le = LabelEncoder()
for i in column:
    df[i] = le.fit_transform(df[i].astype(str))

print(df.dtypes)
# Out:
# Date              int64
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type              int32
# year              int64
# region            int32
# Month             int64
# dtype: object

# %%
df.head()
# Out:
#    Date  AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0    27          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1    20          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2    13          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3     6          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4    29          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags  type  year  region  Month
# 0     8603.62       93.25          0.0     0  2015       0     12
# 1     9408.07       97.49          0.0     0  2015       0     12
# 2     8042.21      103.14          0.0     0  2015       0     12
# 3     5677.40      133.76          0.0     0  2015       0     12
# 4     5986.26      197.69          0.0     0  2015       0     11

# %%
df.type  =df.type.astype(float)

# %%
#plotting the boxplot of each column to check the outliers 
df.plot(kind='box',subplots = True,layout=(4,5),figsize = (15,10))
# Out:
# Date                AxesSubplot(0.125,0.71587;0.133621x0.16413)
# AveragePrice     AxesSubplot(0.285345,0.71587;0.133621x0.16413)
# Total Volume      AxesSubplot(0.44569,0.71587;0.133621x0.16413)
# 4046             AxesSubplot(0.606034,0.71587;0.133621x0.16413)
# 4225             AxesSubplot(0.766379,0.71587;0.133621x0.16413)
# 4770               AxesSubplot(0.125,0.518913;0.133621x0.16413)
# Total Bags      AxesSubplot(0.285345,0.518913;0.133621x0.16413)
# Small Bags       AxesSubplot(0.44569,0.518913;0.133621x0.16413)
# Large Bags      AxesSubplot(0.606034,0.518913;0.133621x0.16413)
# XLarge Bags     AxesSubplot(0.766379,0.518913;0.133621x0.16413)
# type               AxesSubplot(0.125,0.321957;0.133621x0.16413)
# year            AxesSubplot(0.285345,0.321957;0.133621x0.16413)
# region           AxesSubplot(0.44569,0.321957;0.133621x0.16413)
# Month           AxesSubplot(0.606034,0.321957;0.133621x0.16413)
# dtype: object

# %%
#calculate the zscore
z = np.abs(zscore(df))
print(z)
# Out:
# [[1.29185687 0.18868864 0.22771641 ... 1.22128204 1.7002522  1.64763162]
#  [0.49423066 0.13901962 0.23042664 ... 1.22128204 1.7002522  1.64763162]
#  [0.30339555 1.18206895 0.21208462 ... 1.22128204 1.7002522  1.64763162]
#  ...
#  [0.60817726 1.15237477 0.24233073 ... 1.97050371 1.70081131 1.46495942]
#  [0.18944895 1.30138182 0.24162464 ... 1.97050371 1.70081131 1.46495942]
#  [0.98707516 0.53151208 0.24125273 ... 1.97050371 1.70081131 1.46495942]]

# %%
#checking the co-relation of all column to each other
df_cor = df.corr()
plt.figure(figsize=(30,25))
sns.heatmap(df_cor,annot=True)
plt.plot()
# Out:
# []

# %% [markdown]
# as year is most negative co related column among all columns and also the difference is very close of each column

# %%
threshold = 3
print(np.where(z<3))
print(df.shape)
# Out:
# (array([    0,     0,     0, ..., 18248, 18248, 18248], dtype=int64), array([ 0,  1,  2, ..., 11, 12, 13], dtype=int64))
# (18249, 14)

# %%
#Assign the value to df_new which are less the threshold value and removing the outliers
df_new = df[(z<3).all(axis = 1)]

# %%
print(df.shape)
print(df_new.shape)
df = df_new
print('Shape after removing outlires',df.shape)
# Out:
# (18249, 14)
# (17651, 14)
# Shape after removing outlires (17651, 14)

# %%
#now finding the mean value of each column 

print(df['4225'].mean())
print(df['Total Bags'].mean())
print(df['Small Bags'].mean())
# Out:
# 165600.94489433893
# 129816.01636961184
# 100628.33843918175

# %%
#replace the outlier value to its mean value to remove outliers
df.loc[df['4225']<3,'4225'] = np.mean(df['4225'])
df.loc[df['Total Bags']<4.8,'Total Bags'] = np.mean(df['Total Bags'])
df.loc[df['Small Bags']<4,'Small Bags'] = np.mean(df['Small Bags'])

# %%
#plotting the boxplot of each column to check the outliers 
df.plot(kind='box',subplots = True,layout=(4,5),figsize = (15,10))
# Out:
# Date                AxesSubplot(0.125,0.71587;0.133621x0.16413)
# AveragePrice     AxesSubplot(0.285345,0.71587;0.133621x0.16413)
# Total Volume      AxesSubplot(0.44569,0.71587;0.133621x0.16413)
# 4046             AxesSubplot(0.606034,0.71587;0.133621x0.16413)
# 4225             AxesSubplot(0.766379,0.71587;0.133621x0.16413)
# 4770               AxesSubplot(0.125,0.518913;0.133621x0.16413)
# Total Bags      AxesSubplot(0.285345,0.518913;0.133621x0.16413)
# Small Bags       AxesSubplot(0.44569,0.518913;0.133621x0.16413)
# Large Bags      AxesSubplot(0.606034,0.518913;0.133621x0.16413)
# XLarge Bags     AxesSubplot(0.766379,0.518913;0.133621x0.16413)
# type               AxesSubplot(0.125,0.321957;0.133621x0.16413)
# year            AxesSubplot(0.285345,0.321957;0.133621x0.16413)
# region           AxesSubplot(0.44569,0.321957;0.133621x0.16413)
# Month           AxesSubplot(0.606034,0.321957;0.133621x0.16413)
# dtype: object

# %% [markdown]
# Now there are no outliers in the data set after removing it through mean value

# %%
print(df.shape)
print(df_new.shape)
df = df_new
print('Shape after removing outlires',df.shape)
# Out:
# (17651, 14)
# (17651, 14)
# Shape after removing outlires (17651, 14)

# %%
df.skew()
# Out:
# Date            0.011778
# AveragePrice    0.377432
# Total Volume    3.767138
# 4046            4.909848
# 4225            4.455664
# 4770            5.117170
# Total Bags      4.066780
# Small Bags      4.222709
# Large Bags      5.053434
# XLarge Bags     6.135607
# type           -0.037741
# year            0.229976
# region          0.012798
# Month           0.107408
# dtype: float64

# %%
#making the skew less than or equal to 0.55 for better prediction and plotting Normal distribution
skew=('Total Volume','4046','4225','4770','Total Bags','Small Bags','Large Bags','XLarge Bags')
for col in skew :
    if df.skew().loc[col]>0.55:
        df[col] = np.log1p(df[col])

# %%
df.skew()
# Out:
# Date            0.011778
# AveragePrice    0.377432
# Total Volume   -0.049950
# 4046           -0.420273
# 4225           -0.503957
# 4770            0.068532
# Total Bags     -0.319074
# Small Bags     -0.435520
# Large Bags     -0.610874
# XLarge Bags     1.216238
# type           -0.037741
# year            0.229976
# region          0.012798
# Month           0.107408
# dtype: float64

# %%
#plotting histogram for univariate analysis and checking the Normal Distribution
df.hist(figsize=(20,20), grid = True, layout = (4,4), bins = 30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001EBAC3F1888>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EBAF2B8448>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EBAF31F408>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EBAF4139C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001EBAF449048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EBAF47D6C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EBAF4B3448>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EBAF4EB1C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001EBAF4F4188>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EBAF521F48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EBAF58C8C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EBAF5C49C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001EBAF5FDB08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EBAF635C08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EBAF66DD08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EBAF6A5F08>]],
#       dtype=object)

# %% [markdown]
# average price, total bags and total volume is well normally distributed data among all column

# %%
#assign the value of x and y for training and testing phase
x = df.drop(columns=['AveragePrice','Date'])
y = df[["AveragePrice"]]
print(x.shape)
print(y.shape)
# Out:
# (17651, 12)
# (17651, 1)

# %% [markdown]
# Above we are using AveragePrice as output variable and used to do the prediction

# %%
#Now by using multiple Algorithms we are calculating the best Algo which suit best for our data set 

model = [DecisionTreeRegressor(),KNeighborsRegressor(),AdaBoostRegressor(),LinearRegression(),GradientBoostingRegressor()]
max_r2_score = 0
for r_state in range(40,90):
    train_x,test_x,train_y,test_y = train_test_split(x,y,random_state = r_state,test_size = 0.33)
    for i in model:
        i.fit(train_x,train_y)
        pre = i.predict(test_x)
        r2_sc = r2_score(test_y,pre)
        print("R2 score correspond to random state " ,r_state ,"is", r2_sc)
        if r2_sc> max_r2_score:
            max_r2_score=r2_sc
            final_state = r_state
            final_model = i
            
print()
print()
print()
print()
print("max R2 score correspond to random state " ,final_state , "is" , max_r2_score ,"and model is",final_model)
# Out:
# R2 score correspond to random state  40 is 0.7549665080922043
# R2 score correspond to random state  40 is 0.8374592350327745
# R2 score correspond to random state  40 is 0.571144241563182
# R2 score correspond to random state  40 is 0.5449264326278509
# R2 score correspond to random state  40 is 0.7503467423884156
# R2 score correspond to random state  41 is 0.7402491466883232
# R2 score correspond to random state  41 is 0.8281730760420748
# R2 score correspond to random state  41 is 0.5459235633895748
# R2 score correspond to random state  41 is 0.5362877321971171
# R2 score correspond to random state  41 is 0.7462086035627709
# R2 score correspond to random state  42 is 0.7219094483506008
# R2 score correspond to random state  42 is 0.8272814301920477
# R2 score correspond to random state  42 is 0.5459978647617079
# R2 score correspond to random state  42 is 0.5428506636427429
# R2 score correspond to random state  42 is 0.7404567208757835
# R2 score correspond to random state  43 is 0.712900200020787
# R2 score correspond to random state  43 is 0.8254308998757397
# R2 score correspond to random state  43 is 0.5575130923700834
# R2 score correspond to random state  43 is 0.5426734613070541
# R2 score correspond to random state  43 is 0.7462789717647456
# R2 score correspond to random state  44 is 0.7326771913949276
# R2 score correspond to random state  44 is 0.8282751057998612
# R2 score correspond to random state  44 is 0.5584808364675506
# R2 score correspond to random state  44 is 0.5275402020432236
# R2 score correspond to random state  44 is 0.7364471087846254
# R2 score correspond to random state  45 is 0.747034634490476
# R2 score correspond to random state  45 is 0.8287714206742463
# R2 score correspond to random state  45 is 0.5631669431967482
# R2 score correspond to random state  45 is 0.5520188607597141
# R2 score correspond to random state  45 is 0.7415355977630591
# R2 score correspond to random state  46 is 0.7203071518730586
# R2 score correspond to random state  46 is 0.8315240017150916
# R2 score correspond to random state  46 is 0.5636420953320507
# R2 score correspond to random state  46 is 0.5527736932611755
# R2 score correspond to random state  46 is 0.749501831376062
# R2 score correspond to random state  47 is 0.735079812538215
# R2 score correspond to random state  47 is 0.827736705602328
# R2 score correspond to random state  47 is 0.5419891796991938
# R2 score correspond to random state  47 is 0.5403460532749906
# R2 score correspond to random state  47 is 0.744718509996889
# R2 score correspond to random state  48 is 0.7602733341315356
# R2 score correspond to random state  48 is 0.8262618225288333
# R2 score correspond to random state  48 is 0.5642193540053038
# R2 score correspond to random state  48 is 0.5459307397846487
# R2 score correspond to random state  48 is 0.7421020741404272
# R2 score correspond to random state  49 is 0.7302839213301129
# R2 score correspond to random state  49 is 0.8255371151040708
# R2 score correspond to random state  49 is 0.5674816034525954
# R2 score correspond to random state  49 is 0.5405653299974152
# R2 score correspond to random state  49 is 0.743276958722356
# R2 score correspond to random state  50 is 0.73785016351541
# R2 score correspond to random state  50 is 0.8331783005731987
# R2 score correspond to random state  50 is 0.5634028342666194
# R2 score correspond to random state  50 is 0.5441328947013282
# R2 score correspond to random state  50 is 0.7404980465085816
# R2 score correspond to random state  51 is 0.7421800653762218
# R2 score correspond to random state  51 is 0.831121559155518
# R2 score correspond to random state  51 is 0.5526918703540067
# R2 score correspond to random state  51 is 0.5425736926744655
# R2 score correspond to random state  51 is 0.7381344181829376
# R2 score correspond to random state  52 is 0.7153557036935845
# R2 score correspond to random state  52 is 0.822661785877112
# R2 score correspond to random state  52 is 0.5709843551234479
# R2 score correspond to random state  52 is 0.5455671667097731
# R2 score correspond to random state  52 is 0.7456063559408379
# R2 score correspond to random state  53 is 0.7489336880529038
# R2 score correspond to random state  53 is 0.8356558890699237
# R2 score correspond to random state  53 is 0.5478489985106532
# R2 score correspond to random state  53 is 0.5506638081964521
# R2 score correspond to random state  53 is 0.7425733362066178
# R2 score correspond to random state  54 is 0.7323698250895676
# R2 score correspond to random state  54 is 0.8373834191353019
# R2 score correspond to random state  54 is 0.557431978008991
# R2 score correspond to random state  54 is 0.5364198520335268
# R2 score correspond to random state  54 is 0.7366008283155208
# R2 score correspond to random state  55 is 0.7203874658694985
# R2 score correspond to random state  55 is 0.8236392318998603
# R2 score correspond to random state  55 is 0.5618429897295907
# R2 score correspond to random state  55 is 0.5319210408803521
# R2 score correspond to random state  55 is 0.7394640425616357
# R2 score correspond to random state  56 is 0.7351373456594655
# R2 score correspond to random state  56 is 0.8211365778573971
# R2 score correspond to random state  56 is 0.5703019457793377
# R2 score correspond to random state  56 is 0.5487437706421957
# R2 score correspond to random state  56 is 0.7454985790568494
# R2 score correspond to random state  57 is 0.7225392658769076
# R2 score correspond to random state  57 is 0.8282536746694267
# R2 score correspond to random state  57 is 0.5623797197912312
# R2 score correspond to random state  57 is 0.5448785337246108
# R2 score correspond to random state  57 is 0.7440428698096813
# R2 score correspond to random state  58 is 0.7392652984351874
# R2 score correspond to random state  58 is 0.837800492602347
# R2 score correspond to random state  58 is 0.5455487474951142
# R2 score correspond to random state  58 is 0.5396438781744749
# R2 score correspond to random state  58 is 0.73995050113008
# R2 score correspond to random state  59 is 0.7230213592928081
# R2 score correspond to random state  59 is 0.8286333668491137
# R2 score correspond to random state  59 is 0.5495550918613816
# R2 score correspond to random state  59 is 0.5347257301559074
# R2 score correspond to random state  59 is 0.7365961044382087
# R2 score correspond to random state  60 is 0.7456731293855571
# R2 score correspond to random state  60 is 0.8364045526135928
# R2 score correspond to random state  60 is 0.573202277107022
# R2 score correspond to random state  60 is 0.5515784282658254
# R2 score correspond to random state  60 is 0.7455751147709284
# R2 score correspond to random state  61 is 0.7212794000150499
# R2 score correspond to random state  61 is 0.8307471928369866
# R2 score correspond to random state  61 is 0.5532325588383645
# R2 score correspond to random state  61 is 0.5380968795656007
# R2 score correspond to random state  61 is 0.7379224667864919
# R2 score correspond to random state  62 is 0.7263765659795228
# R2 score correspond to random state  62 is 0.8243446530267169
# R2 score correspond to random state  62 is 0.5648444241665176
# R2 score correspond to random state  62 is 0.535059575139535
# R2 score correspond to random state  62 is 0.7388685119565532
# R2 score correspond to random state  63 is 0.7412062555947084
# R2 score correspond to random state  63 is 0.8366588134220052
# R2 score correspond to random state  63 is 0.5588584887497632
# R2 score correspond to random state  63 is 0.5516086346586662
# R2 score correspond to random state  63 is 0.7490698061634051
# R2 score correspond to random state  64 is 0.723647369398374
# R2 score correspond to random state  64 is 0.8325309005331549
# R2 score correspond to random state  64 is 0.5517518791028706
# R2 score correspond to random state  64 is 0.5457698106297872
# R2 score correspond to random state  64 is 0.7429271317485653
# R2 score correspond to random state  65 is 0.7451007777310773
# R2 score correspond to random state  65 is 0.8300652444678993
# R2 score correspond to random state  65 is 0.5620562793342041
# R2 score correspond to random state  65 is 0.5436223611351709
# R2 score correspond to random state  65 is 0.7441746103556772
# R2 score correspond to random state  66 is 0.7494518915200526
# R2 score correspond to random state  66 is 0.8324690927179246
# R2 score correspond to random state  66 is 0.5337856282398306
# R2 score correspond to random state  66 is 0.5296878225910446
# R2 score correspond to random state  66 is 0.7401223664861444
# R2 score correspond to random state  67 is 0.7465071840731392
# R2 score correspond to random state  67 is 0.8245760924899006
# R2 score correspond to random state  67 is 0.5560802106963514
# R2 score correspond to random state  67 is 0.5467764048273747
# R2 score correspond to random state  67 is 0.7379547916451867
# R2 score correspond to random state  68 is 0.7212728587926451
# R2 score correspond to random state  68 is 0.8288543911975044
# R2 score correspond to random state  68 is 0.5599248495431537
# R2 score correspond to random state  68 is 0.5418675232604921
# R2 score correspond to random state  68 is 0.7438324409182258
# R2 score correspond to random state  69 is 0.7295186041385966
# R2 score correspond to random state  69 is 0.8362636786863729
# R2 score correspond to random state  69 is 0.5564366119588522
# R2 score correspond to random state  69 is 0.5515609013985068
# R2 score correspond to random state  69 is 0.7414935075703877
# R2 score correspond to random state  70 is 0.7292578334288169
# R2 score correspond to random state  70 is 0.8259193498589109
# R2 score correspond to random state  70 is 0.562629895152098
# R2 score correspond to random state  70 is 0.5391791327250355
# R2 score correspond to random state  70 is 0.7356682970635952
# R2 score correspond to random state  71 is 0.739423855145553
# R2 score correspond to random state  71 is 0.8322288213161559
# R2 score correspond to random state  71 is 0.5690732800846674
# R2 score correspond to random state  71 is 0.540003945230336
# R2 score correspond to random state  71 is 0.7422911160642607
# R2 score correspond to random state  72 is 0.740054300752873
# R2 score correspond to random state  72 is 0.83007616976478
# R2 score correspond to random state  72 is 0.5604797720682597
# R2 score correspond to random state  72 is 0.5399929538086452
# R2 score correspond to random state  72 is 0.735625654882194
# R2 score correspond to random state  73 is 0.7242240161735078
# R2 score correspond to random state  73 is 0.8255533192504672
# R2 score correspond to random state  73 is 0.5367011492605684
# R2 score correspond to random state  73 is 0.5339701090272548
# R2 score correspond to random state  73 is 0.7353069178777809
# R2 score correspond to random state  74 is 0.7298839013583795
# R2 score correspond to random state  74 is 0.8317553435207302
# R2 score correspond to random state  74 is 0.5394103463961044
# R2 score correspond to random state  74 is 0.5408886901133597
# R2 score correspond to random state  74 is 0.7412176951461382
# R2 score correspond to random state  75 is 0.7518031909187242
# R2 score correspond to random state  75 is 0.8364627231768833
# R2 score correspond to random state  75 is 0.5712648642367636
# R2 score correspond to random state  75 is 0.5490056865021623
# R2 score correspond to random state  75 is 0.7438514524156747
# R2 score correspond to random state  76 is 0.7284210472099895
# R2 score correspond to random state  76 is 0.8270297808162538
# R2 score correspond to random state  76 is 0.560781189336835
# R2 score correspond to random state  76 is 0.5499547905809268
# R2 score correspond to random state  76 is 0.7512256588452967
# R2 score correspond to random state  77 is 0.7339183828285074
# R2 score correspond to random state  77 is 0.8297811266121835
# R2 score correspond to random state  77 is 0.5650883010175647
# R2 score correspond to random state  77 is 0.5438975920588359
# R2 score correspond to random state  77 is 0.7456641055461449
# R2 score correspond to random state  78 is 0.729128315355897
# R2 score correspond to random state  78 is 0.8311487308801586
# R2 score correspond to random state  78 is 0.5574030580483015
# R2 score correspond to random state  78 is 0.5400314032503444
# R2 score correspond to random state  78 is 0.7455297937335523
# R2 score correspond to random state  79 is 0.752718880359159
# R2 score correspond to random state  79 is 0.8328347273853847
# R2 score correspond to random state  79 is 0.5512860234887773
# R2 score correspond to random state  79 is 0.5487928856234007
# R2 score correspond to random state  79 is 0.7494572388386154
# R2 score correspond to random state  80 is 0.7413053419963083
# R2 score correspond to random state  80 is 0.8251132033066886
# R2 score correspond to random state  80 is 0.5543603047557267
# R2 score correspond to random state  80 is 0.5439939688602626
# R2 score correspond to random state  80 is 0.744517671062311
# R2 score correspond to random state  81 is 0.7502403766018569
# R2 score correspond to random state  81 is 0.8251996117019649
# R2 score correspond to random state  81 is 0.5488441092893489
# R2 score correspond to random state  81 is 0.5339344704217136
# R2 score correspond to random state  81 is 0.7359685896739221
# R2 score correspond to random state  82 is 0.731356422541255
# R2 score correspond to random state  82 is 0.8342654972675346
# R2 score correspond to random state  82 is 0.5714527536495242
# R2 score correspond to random state  82 is 0.5539792936479919
# R2 score correspond to random state  82 is 0.7404763300403505
# R2 score correspond to random state  83 is 0.7562069592578116
# R2 score correspond to random state  83 is 0.833774378270632
# R2 score correspond to random state  83 is 0.559500891686324
# R2 score correspond to random state  83 is 0.5461346326228438
# R2 score correspond to random state  83 is 0.744679744909034
# R2 score correspond to random state  84 is 0.7353762408042542
# R2 score correspond to random state  84 is 0.8295155050754535
# R2 score correspond to random state  84 is 0.563647101137746
# R2 score correspond to random state  84 is 0.5399773290271972
# R2 score correspond to random state  84 is 0.7443897881300161
# R2 score correspond to random state  85 is 0.7412762333501491
# R2 score correspond to random state  85 is 0.8355182334263149
# R2 score correspond to random state  85 is 0.5782253693464372
# R2 score correspond to random state  85 is 0.5455092258707269
# R2 score correspond to random state  85 is 0.7378961802994755
# R2 score correspond to random state  86 is 0.7470487632839546
# R2 score correspond to random state  86 is 0.8265417224250098
# R2 score correspond to random state  86 is 0.566558262736448
# R2 score correspond to random state  86 is 0.5397618469724217
# R2 score correspond to random state  86 is 0.7357351731319746
# R2 score correspond to random state  87 is 0.7399259449275363
# R2 score correspond to random state  87 is 0.8293433914538293
# R2 score correspond to random state  87 is 0.5425058410149062
# R2 score correspond to random state  87 is 0.5382522612529976
# R2 score correspond to random state  87 is 0.7376051180686848
# R2 score correspond to random state  88 is 0.7608458518433519
# R2 score correspond to random state  88 is 0.841564614027358
# R2 score correspond to random state  88 is 0.5652629192695637
# R2 score correspond to random state  88 is 0.5439478810138688
# R2 score correspond to random state  88 is 0.7426867537347857
# R2 score correspond to random state  89 is 0.7350408315751975
# R2 score correspond to random state  89 is 0.8327620536074403
# R2 score correspond to random state  89 is 0.5557376185468863
# R2 score correspond to random state  89 is 0.5526041014605145
# R2 score correspond to random state  89 is 0.7490239788939307
#
#
#
#
# max R2 score correspond to random state  88 is 0.841564614027358 and model is KNeighborsRegressor()

# %% [markdown]
# max R2 score correspond to random state  80 is 0.8500661139863255 and model is KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                     weights='uniform')

# %%
#Checking the best parameter for prediction of KNeighborsRegressor Algo using GridSearchCV
train_x,test_x,train_y,test_y = train_test_split(x,y,random_state = 80,test_size = 0.33)
KNC = KNeighborsRegressor()
parameters={'n_neighbors' : range(1,30)}
gridsearch=GridSearchCV(KNC,parameters)
gridsearch.fit(train_x,train_y)
gridsearch.best_params_
# Out:
# {'n_neighbors': 2}

# %%
KNN = KNeighborsRegressor(n_neighbors=2)
KNN.fit(train_x,train_y)
pred = KNN.predict(test_x)
r2_sc = r2_score(test_y,pred)
print("R2 Score :",r2_sc*100)
# Out:
# R2 Score : 84.27027942766398

# %%
print('Mean Absolute Error: ', mean_absolute_error(test_y,pred))
print('Mean squared Error: ', mean_squared_error(test_y,pred))
print('Root Mean Absolute Error: ', np.sqrt(mean_absolute_error(test_y,pred)))
# Out:
# Mean Absolute Error:  0.10332274678111589
# Mean squared Error:  0.022744725321888412
# Root Mean Absolute Error:  0.32143855832976215

# %%
#checking the diff between actual and predicted value using graph
plt.scatter(x=test_y,y=pred)
plt.xlabel('Y_Test')
plt.ylabel('Predicted_Y')
# Out:
# Text(0, 0.5, 'Predicted_Y')

# %% [markdown]
# As above graph shown that it is predicting near to tha actual value and RMSE error is very less

# %%
#importing library for classification prediction
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,roc_auc_score,roc_curve
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier

# %%
#assign the value of x and y for training and testing phase
x_c = df.drop(columns=['region','Date'])
y_c = df[["region"]]
print(x_c.shape)
print(y_c.shape)
# Out:
# (17651, 12)
# (17651, 1)

# %%
#Standardize the value of x so that mean will 0 and SD will become 1 , and make the data as normal distributed
sc = StandardScaler()
sc.fit_transform(x_c)
x_c = pd.DataFrame(x_c,columns=x_c.columns)

# %% [markdown]
# now we are taking region as output variable and try to prediction using classification method

# %%
#Now by using multiple Algorithms we are calculating the best Algo which suit best for our data set 

model = [DecisionTreeClassifier(),KNeighborsClassifier()]
max_accuracy_score = 0
for r_state in range(40,90):
    train_xc,test_xc,train_yc,test_yc = train_test_split(x_c,y_c,random_state = r_state,test_size = 0.33)
    for i_c in model:
        i_c.fit(train_xc,train_yc)
        pre_c = i_c.predict(test_xc)
        ac_score = accuracy_score(test_yc,pre_c)
        print("accuracy score correspond to random state " ,r_state ,"is", ac_score)
        if ac_score> max_accuracy_score:
            max_accuracy_score=ac_score
            final_state = r_state
            final_model = i_c
            
print()
print()
print()
print()

print("max accuracy score correspond to random state " ,final_state , "is" , max_accuracy_score ,"and model is",final_model)
# Out:
# accuracy score correspond to random state  40 is 0.783519313304721
# accuracy score correspond to random state  40 is 0.7787124463519314
# accuracy score correspond to random state  41 is 0.775793991416309
# accuracy score correspond to random state  41 is 0.783519313304721
# accuracy score correspond to random state  42 is 0.7790557939914163
# accuracy score correspond to random state  42 is 0.7809442060085837
# accuracy score correspond to random state  43 is 0.7840343347639485
# accuracy score correspond to random state  43 is 0.7783690987124463
# accuracy score correspond to random state  44 is 0.7874678111587983
# accuracy score correspond to random state  44 is 0.7788841201716739
# accuracy score correspond to random state  45 is 0.784549356223176
# accuracy score correspond to random state  45 is 0.7866094420600859
# accuracy score correspond to random state  46 is 0.7898712446351931
# accuracy score correspond to random state  46 is 0.7933047210300429
# accuracy score correspond to random state  47 is 0.7787124463519314
# accuracy score correspond to random state  47 is 0.7799141630901287
# accuracy score correspond to random state  48 is 0.7893562231759657
# accuracy score correspond to random state  48 is 0.7811158798283262
# accuracy score correspond to random state  49 is 0.7792274678111588
# accuracy score correspond to random state  49 is 0.7831759656652361
# accuracy score correspond to random state  50 is 0.7869527896995708
# accuracy score correspond to random state  50 is 0.7884978540772533
# accuracy score correspond to random state  51 is 0.7812875536480687
# accuracy score correspond to random state  51 is 0.7783690987124463
# accuracy score correspond to random state  52 is 0.7890128755364807
# accuracy score correspond to random state  52 is 0.7879828326180257
# accuracy score correspond to random state  53 is 0.7843776824034335
# accuracy score correspond to random state  53 is 0.7833476394849785
# accuracy score correspond to random state  54 is 0.7881545064377682
# accuracy score correspond to random state  54 is 0.7840343347639485
# accuracy score correspond to random state  55 is 0.7800858369098712
# accuracy score correspond to random state  55 is 0.791244635193133
# accuracy score correspond to random state  56 is 0.783862660944206
# accuracy score correspond to random state  56 is 0.7804291845493562
# accuracy score correspond to random state  57 is 0.7812875536480687
# accuracy score correspond to random state  57 is 0.7723605150214592
# accuracy score correspond to random state  58 is 0.7878111587982832
# accuracy score correspond to random state  58 is 0.7847210300429185
# accuracy score correspond to random state  59 is 0.783862660944206
# accuracy score correspond to random state  59 is 0.7909012875536481
# accuracy score correspond to random state  60 is 0.792274678111588
# accuracy score correspond to random state  60 is 0.7893562231759657
# accuracy score correspond to random state  61 is 0.7857510729613734
# accuracy score correspond to random state  61 is 0.7821459227467811
# accuracy score correspond to random state  62 is 0.784892703862661
# accuracy score correspond to random state  62 is 0.7872961373390558
# accuracy score correspond to random state  63 is 0.7780257510729613
# accuracy score correspond to random state  63 is 0.7811158798283262
# accuracy score correspond to random state  64 is 0.7802575107296137
# accuracy score correspond to random state  64 is 0.7914163090128755
# accuracy score correspond to random state  65 is 0.7831759656652361
# accuracy score correspond to random state  65 is 0.7826609442060086
# accuracy score correspond to random state  66 is 0.7890128755364807
# accuracy score correspond to random state  66 is 0.7934763948497854
# accuracy score correspond to random state  67 is 0.7818025751072961
# accuracy score correspond to random state  67 is 0.7872961373390558
# accuracy score correspond to random state  68 is 0.7840343347639485
# accuracy score correspond to random state  68 is 0.7874678111587983
# accuracy score correspond to random state  69 is 0.7867811158798284
# accuracy score correspond to random state  69 is 0.7828326180257511
# accuracy score correspond to random state  70 is 0.7830042918454936
# accuracy score correspond to random state  70 is 0.7843776824034335
# accuracy score correspond to random state  71 is 0.7917596566523605
# accuracy score correspond to random state  71 is 0.7878111587982832
# accuracy score correspond to random state  72 is 0.7818025751072961
# accuracy score correspond to random state  72 is 0.7876394849785407
# accuracy score correspond to random state  73 is 0.7872961373390558
# accuracy score correspond to random state  73 is 0.7867811158798284
# accuracy score correspond to random state  74 is 0.7898712446351931
# accuracy score correspond to random state  74 is 0.7896995708154506
# accuracy score correspond to random state  75 is 0.7878111587982832
# accuracy score correspond to random state  75 is 0.7890128755364807
# accuracy score correspond to random state  76 is 0.7739055793991416
# accuracy score correspond to random state  76 is 0.7888412017167382
# accuracy score correspond to random state  77 is 0.7778540772532189
# accuracy score correspond to random state  77 is 0.7787124463519314
# accuracy score correspond to random state  78 is 0.7902145922746782
# accuracy score correspond to random state  78 is 0.7852360515021459
# accuracy score correspond to random state  79 is 0.7994849785407725
# accuracy score correspond to random state  79 is 0.7910729613733906
# accuracy score correspond to random state  80 is 0.7857510729613734
# accuracy score correspond to random state  80 is 0.791931330472103
# accuracy score correspond to random state  81 is 0.783519313304721
# accuracy score correspond to random state  81 is 0.7807725321888412
# accuracy score correspond to random state  82 is 0.7903862660944206
# accuracy score correspond to random state  82 is 0.7855793991416309
# accuracy score correspond to random state  83 is 0.7924463519313305
# accuracy score correspond to random state  83 is 0.7807725321888412
# accuracy score correspond to random state  84 is 0.7859227467811158
# accuracy score correspond to random state  84 is 0.7936480686695279
# accuracy score correspond to random state  85 is 0.7780257510729613
# accuracy score correspond to random state  85 is 0.7831759656652361
# accuracy score correspond to random state  86 is 0.7797424892703863
# accuracy score correspond to random state  86 is 0.7962231759656653
# accuracy score correspond to random state  87 is 0.7806008583690988
# accuracy score correspond to random state  87 is 0.7879828326180257
# accuracy score correspond to random state  88 is 0.7945064377682404
# accuracy score correspond to random state  88 is 0.7862660944206008
# accuracy score correspond to random state  89 is 0.7867811158798284
# accuracy score correspond to random state  89 is 0.7871244635193133
#
#
#
#
# max accuracy score correspond to random state  79 is 0.7994849785407725 and model is DecisionTreeClassifier()

# %%
#Checking the best parameter for prediction of KNeighborsClassifier Algo using GridSearchCV
train_xc,test_xc,train_yc,test_yc = train_test_split(x_c,y_c,random_state = 76,test_size = 0.33)
KNC = KNeighborsClassifier()
parameters={'n_neighbors' : range(1,30)}
gridsearch=GridSearchCV(KNC,parameters)
gridsearch.fit(train_xc,train_yc)
gridsearch.best_params_
# Out:
# {'n_neighbors': 1}

# %%
KNC = KNeighborsClassifier(n_neighbors=1)
KNC.fit(train_xc,train_yc)
predc = KNC.predict(test_xc)
acu_score = accuracy_score(test_yc,predc)
print("Accuracy Score :",acu_score*100)
# Out:
# Accuracy Score : 83.53648068669528

# %%
#Calculating the scores of different parameters
score = cross_val_score(KNC,x_c,y_c,cv = 100,scoring='accuracy').mean()
print('Cross_val_score : ', score*100)
print('Mean Score      : ' , score.mean()*100)
print('STD score       : ' , score.std())
# Out:
# Cross_val_score :  80.05164997431949
# Mean Score      :  80.05164997431949
# STD score       :  0.0

# %%
pred_prob = KNC.predict_proba(test_xc)[:,1]
pred_prob
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
fpr,tpr,thresholds = roc_curve(test_yc,pred_prob,pos_label=True)

# %%
print(fpr)
print("\n")
print(tpr)
print("\n")
print(thresholds)
# Out:
# [0.         0.00472276 1.        ]
#
#
# [0.        0.7962963 1.       ]
#
#
# [2. 1. 0.]

# %%
#Plotting the graph which tells us about the area under curve , more the area under curve more will be the better prediction

plt.plot([0,1],[1,0],'k--')
plt.plot(fpr,tpr,label = 'KNeighborsClassifier')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('KNeighborsClassifier')
plt.show()

# %%
import pickle

# %%
# save the model to disk
filename = 'finalized_model.sav'
pickle.dump(model, open(filename, 'wb'))

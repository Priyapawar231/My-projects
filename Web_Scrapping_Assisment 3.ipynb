# %%
## importing libraries
import selenium
import pandas as pd
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException

# %% [markdown]
# # 1. Write a python program which searches all the product under a particular product vertical from www.amazon.in. The product verticals to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for guitars.
# # 2. In the above question, now scrape the following details of each product listed in first 3 pages of your search results and save it in a data frame and csv. In case if any product vertical has less than 3 pages in search results then scrape all the products available under that product vertical. Details to be scraped are: "Brand Name", "Name of the Product", "Rating", "No. of Ratings", "Price", "Return/Exchange", "Expected Delivery", "Availability", "Other Details" and “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
driver=webdriver.Chrome(r"C:\Users\rksan\Downloads\chromedriver_win32\chromedriver.exe")
driver.get('https://www.amazon.in/')

# %%
try:
    product_elem = driver.find_element_by_id('twotabsearchtextbox').send_keys(input("Type product, For e.g: guitars \n>> "))
    
except:
    print("Element Not Found!")

search = driver.find_element_by_xpath("//div[@class='nav-search-submit nav-sprite']").click()
time.sleep(1)
Brand_Name=[]
NameoftheProduct=[]
Rating=[]
NoofRatings=[]
Price=[]
Return_Exchange=[]
ExpectedDelivery=[]
Availability=[]
OtherDetails=[] 
ProductURL=[]
time.sleep(1)
urls=[]
for i in driver.find_elements_by_xpath("//a[@class='a-link-normal s-no-outline']"):
    urls.append(i.get_attribute("href"))
    
for i in urls:
    driver.get(i)
    time.sleep(1)
    try:
        Brand=driver.find_element_by_xpath("//td[@class='a-span9']//span")
        Brand_Name.append(Brand.text.replace("/n","new line"))
    except:
        Brand_Name.append("-")
        
    try:
        Name=driver.find_element_by_xpath("//h1[@id='title']//span")
        NameoftheProduct.append(Name.text.replace("/n","new line"))
    except:
        NameoftheProduct.append("-")
        
    try:
        Ratins=driver.find_element_by_xpath("//span[@class='a-size-base a-nowrap']")
        Rating.append(Ratins.text.replace("/n","new line"))
    except:
        Rating.append("-")
    
    try:
        Ratings=driver.find_element_by_xpath("//a[@id='acrCustomerReviewLink']//span")
        NoofRatings.append(Ratings.text.replace("/n","new line"))
    except:
        NoofRatings.append("-")
        
    try:
        Pric=driver.find_element_by_xpath("//td[@class='a-span12']//span")
        Price.append(Pric.text.replace("/n","new line"))
    except:
        Price.append("-")
        
    try:
        Return_Exc=driver.find_element_by_xpath("//div[@id='RETURNS_POLICY']")
        Return_Exchange.append(Return_Exc.text.replace("/n","new line"))
    except:
        Return_Exchange.append("-")
        
    try:
        Expected=driver.find_element_by_xpath("//div[@id='ddmDeliveryMessage']//b")
        ExpectedDelivery.append(Expected.text.replace("/n","new line"))
    except:
        ExpectedDelivery.append("-")
        
    try:
        Availabi=driver.find_element_by_xpath("//div[@id='availability']")
        Availability.append(Availabi.text.replace("/n","new line"))
    except:
        Availability.append("-")
    
    try:
        OtherDetail=driver.find_element_by_xpath("//div[@id='feature-bullets']")
        OtherDetails.append(OtherDetail.text.replace("/n","new line"))
    except:
        OtherDetails.append("-")
    
    try:
        Product=driver.find_element_by_xpath("//div[@id='bylineInfo_feature_div']")
        ProductURL.append(Product.get_attribute(href))
        
    except:
        ProductURL.append("-")
time.sleep(1)
Product_list = pd.DataFrame({})
Product_list["Brand_Names"]=Brand_Name
Product_list["Name_of_the_Product"]=NameoftheProduct
Product_list["Customer Rating"]=Rating
Product_list["No_of_Ratings"]=NoofRatings
Product_list["Price_List"]=Price
Product_list["ReturnorExchange"]=Return_Exchange
Product_list["Expected_Delivery"]=ExpectedDelivery
Product_list["Aarvailability_Status"]=Availability
Product_list["Other_Details"]=OtherDetails 
Product_list["Product_URL"]=ProductURL
Product_list
# Out:
# Type product, For e.g: guitars
# >> guitars
#                  Brand_Names  \
# 0                    Kadence
# 1                    Kadence
# 2                 Guitar Bro
# 3                   Honestum
# 4                     Juârez
# 5                     JUAREZ
# 6                     Juârez
# 7                     JUAREZ
# 8                     HOVNER
# 9                     JUAREZ
# 10                    JUAREZ
# 11                  Medellin
# 12                    Juârez
# 13                   Kadence
# 14                    JUAREZ
# 15                    JUAREZ
# 16                    Intern
# 17                    Jixing
# 18                    YAMAHA
# 19                    JUAREZ
# 20                         -
# 21                    Silver
# 22                         -
# 23  DEVICE OF URBAN INFOTECH
# 24                    Crizer
# 25                  SHOPECOM
# 26         SAAN Life Science
# 27                SG Musical
# 28                     RISER
# ...

# %% [markdown]
# # 4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”, “Secondary Camera”, “Display Size”, “Display Resolution”, “Processor”, “Processor Cores”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
driver=webdriver.Chrome(r"C:\Users\rksan\Downloads\chromedriver_win32\chromedriver.exe")
driver.get('https://www.flipkart.com')

# %%
skip = driver.find_element_by_xpath("//button[@class='_2KpZ6l _2doB4z']").click()
time.sleep(1)
try:
    product_elem = driver.find_element_by_xpath("//input[@class='_3704LK']").send_keys(input("Type product, For e.g: Smartphone \n>> "))
except:
    print("Element Not Found!")

search = driver.find_element_by_xpath("//button[@class='L0Z3Pu']").click()
time.sleep(10)

BrandName=[]
Smartphonename=[]
colour=[]
ram=[] 
storage_ROM=[]
primarycamera=[]
secondarycamera=[]
displaysize=[]
displayresolution=[]
processor=[]
processorcores=[]
batterycapacity=[]
price=[]
productURL=[]

urls=[]
for i in driver.find_elements_by_xpath("//a[@class='_1fQZEK']"):
    urls.append(i.get_attribute("href"))

for i in urls:
    driver.get(i)
    time.sleep(2)
    try:
        Brand=driver.find_element_by_xpath("//div[4][@class='_3GIHBu']")
        BrandName.append(Brand.text.replace("/n","new line"))
    except:
        BrandName.append("-")
        
    try:
        Smartphone=driver.find_element_by_xpath("//div[5][@class='_3GIHBu']").text.replace("/n","new line")
        Smartphonenam= Smartphone.split("(")
        Smartphonename.append(Smartphonenam[0])
        colou=Smartphonenam[1].split(",")
        colour.append(colou[0])
        storage=colou[1].split(")")
        storage_ROM.append(storage[0])
        ra=Smartphonenam[2].split(")")
        ram.append(ra[0])
    except:
        Smartphonename.append("-")
        
    try:
        primary=driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[8]/div[1]/div/div[2]/ul/li[3]").text.replace("/n","new line")
        primarycamer= primary.split("|")
        primarycamera.append(primarycamer[0])
    except:
        primarycamera.append("-")
    
    try:
        primary=driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[8]/div[1]/div/div[2]/ul/li[3]").text.replace("/n","new line")
        primarycamer= primary.split("|")
        secondarycamera.append(primarycamer[1])
    except:
        secondarycamera.append("-")
        
    try:
        displaysiz=driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[8]/div[1]/div/div[2]/ul/li[2]")
        displaysize.append(displaysiz.text.replace("/n","new line"))
    except:
        displaysize.append("-")
        
    try:
        displayresolutio=driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[5]/div/div[2]/div[1]/div[3]/table/tbody/tr[2]/td[2]/ul/li")
        displayresolution.append(displayresolutio.text.replace("/n","new line"))
    except:
        displayresolution.append("-")
        
    try:
        processo=driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[8]/div[1]/div/div[2]/ul/li[5]")
        processor.append(processo.text.replace("/n","new line"))
    except:
        processor.append("-")
        
    try:
        processorcore=driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[5]/div/div[2]/div[1]/div[4]/table/tbody/tr[3]/td[2]/ul/li")
        processorcores.append(processorcore.text.replace("/n","new line"))
    except:
        processorcores.append("-")
        
    try:
        batterycapacit=driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[8]/div[1]/div/div[2]/ul/li[4]")
        batterycapacity.append(batterycapacit.text.replace("/n","new line"))
    except:
        batterycapacity.append("-")
        
    try:
        pric=driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[2]/div/div[4]/div[1]/div/div[1]")
        price.append(pric.text.replace("/n","new line"))
    except:
        price.append("-")
        
time.sleep(1)
Smart_phone = pd.DataFrame({})
Smart_phone["Brand_Name"]=BrandName
Smart_phone["SmartPhoneName"]=Smartphonename
Smart_phone["Colour"]=colour
Smart_phone["RAM"]=ram
Smart_phone["Storage_ROM"]=storage_ROM
Smart_phone["Primarycamera"]=primarycamera
Smart_phone["Secondarycamera"]=secondarycamera
Smart_phone["Displaysize"]=displaysize
Smart_phone["Displayresolution"]=displayresolution
Smart_phone["Processor"]=processor
Smart_phone["Processorcores"]=processorcores
Smart_phone["Batterycapacity"]=batterycapacity
Smart_phone["Price"]=price
Smart_phone
# Out:
# Type product, For e.g: Smartphone
# >> smartphone
#           Brand_Name       SmartPhoneName          Colour       RAM  \
# 0     realme Mobiles          realme C20        Cool Grey  2 GB RAM
# 1     realme Mobiles          realme C20        Cool Blue  2 GB RAM
# 2       POCO Mobiles             POCO C3      Arctic Blue  3 GB RAM
# 3       POCO Mobiles             POCO C3      Matte Black  3 GB RAM
# 4       POCO Mobiles             POCO M3        Cool Blue  4 GB RAM
# 5    Infinix Mobiles     Infinix Smart 5    Morandi Green  2 GB RAM
# 6    Infinix Mobiles     Infinix Smart 5   Obsidian Black  2 GB RAM
# 7    Infinix Mobiles     Infinix Smart 5        7° Purple  2 GB RAM
# 8    Infinix Mobiles     Infinix Smart 5      Aegean Blue  2 GB RAM
# 9       POCO Mobiles             POCO M3           Yellow  4 GB RAM
# 10      POCO Mobiles             POCO M3      Power Black  4 GB RAM
# 11      POCO Mobiles             POCO M3        Cool Blue  6 GB RAM
# ...
